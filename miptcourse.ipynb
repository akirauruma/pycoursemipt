# %% [markdown]
# ## Lab 1

# %%
import numpy as np
import matplotlib.pyplot as plt

x = [1, 10, 100]
y = np.log(1) + x[0]**2 * (((1)/(np.e**np.sin(x[0]) + 1))/((5/4)+(1/(x[0] * 5))))
print(y)
# Out:
# 0.20774142625470682

# %%
x = np.arange(-10, 10.01, 0.01)
plt.plot(x, x**2)
plt.show()

# %%
plt.plot(x, np.sin(x), x, np.cos(x), x, x)
plt.xlabel(r'$x$')
plt.ylabel(r'$f(x)$')
plt.title(r'$f_1(x) = \sin(x), f_2(x) = \cos(x), f_3(x) = x$')
plt.grid(True)
plt.show()
